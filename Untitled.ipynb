# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\varsh\anaconda3\lib\site-packages (23.3.2)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 409.6 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/2.1 MB 409.6 kB/s eta 0:00:06
#    -- ------------------------------------- 0.2/2.1 MB 612.6 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.1 MB 655.9 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.1 MB 749.3 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 791.9 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/2.1 MB 832.3 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.1 MB 851.3 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.1 MB 851.3 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 900.2 kB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.1 MB 900.2 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/2.1 MB 742.9 kB/s eta 0:00:03
#    ------------ --------------------------- 0.7/2.1 MB 887.5 kB/s eta 0:00:02
#    -------------- ------------------------- 0.7/2.1 MB 908.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 929.8 kB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 929.8 kB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 929.8 kB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.1 MB 829.4 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.9/2.1 MB 871.3 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.9/2.1 MB 871.3 kB/s eta 0:00:02
#    -------------------- ------------------- 1.1/2.1 MB 925.2 kB/s eta 0:00:02
#    -------------------- ------------------- 1.1/2.1 MB 925.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.2/2.1 MB 979.2 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.1 MB 975.2 kB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 991.2 kB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 968.1 kB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.1 MB 983.2 kB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.1 MB 969.6 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 980.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 980.3 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 973.7 kB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 974.0 kB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.1 MB 977.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 986.2 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.1 MB 980.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 983.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 983.0 kB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 986.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 986.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 986.2 kB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 975.7 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 968.6 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 973.7 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 973.7 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 927.1 kB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# Successfully installed pip-24.0

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: keras in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (2.15.0)
# Requirement already satisfied: numpy in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.26.3)
# Requirement already satisfied: pandas in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (2.1.4)
# Requirement already satisfied: jupyter in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: notebook in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (7.0.6)
# Requirement already satisfied: tqdm in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (4.65.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\varsh\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: packaging in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varsh\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varsh\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\varsh\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2023.3)
# Requirement already satisfied: qtconsole in c:\users\varsh\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\varsh\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\varsh\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\varsh\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (6.25.0)
# Requirement already satisfied: ipywidgets in c:\users\varsh\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (8.0.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from notebook->-r requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\varsh\anaconda3\lib\site-packages (from notebook->-r requirements.txt (line 6)) (2.25.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\varsh\anaconda3\lib\site-packages (from notebook->-r requirements.txt (line 6)) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\varsh\anaconda3\lib\site-packages (from notebook->-r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from notebook->-r requirements.txt (line 6)) (6.3.3)
# Requirement already satisfied: colorama in c:\users\varsh\anaconda3\lib\site-packages (from tqdm->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.9.2)
# Requirement already satisfied: overrides in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: websocket-client in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\varsh\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\varsh\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (8.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.5.6)
# Requirement already satisfied: psutil in c:\users\varsh\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\varsh\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\varsh\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 5)) (3.0.43)
# Requirement already satisfied: ipython-genutils in c:\users\varsh\anaconda3\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: idna>=2.8 in c:\users\varsh\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\varsh\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.38.4)
# Requirement already satisfied: webencodings in c:\users\varsh\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: decorator in c:\users\varsh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\varsh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\varsh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\varsh\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\varsh\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 6)) (2023.11.17)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\varsh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\varsh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\varsh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\varsh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\varsh\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varsh\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 5)) (2.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\varsh\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: fqdn in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.1)
# Requirement already satisfied: uri-template in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: executing in c:\users\varsh\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\varsh\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\varsh\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\varsh\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow->-r requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\varsh\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.2.3)

# %%
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
import os
import pandas as pd
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_path=[]
    labels=[]
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_path.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "Done Completion")
    return image_path, labels

# %%
train= pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry Done Completion
# disgust Done Completion
# fear Done Completion
# happy Done Completion
# neutral Done Completion
# sad Done Completion
# surprise Done Completion

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test= pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry Done Completion
# disgust Done Completion
# fear Done Completion
# happy Done Completion
# neutral Done Completion
# sad Done Completion
# surprise Done Completion

# %%
print(test)
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, grayscale= True)
        img = np.array(img)
        features.append(img)
    features=np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features= extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
print(train_features)
# Out:
# [[[[ 72]
#    [ 78]
#    [ 81]
#    ...
#    [ 52]
#    [ 43]
#    [ 40]]
#
#   [[ 65]
#    [ 62]
#    [ 59]
#    ...
#    [ 55]
#    [ 52]
#    [ 45]]
#
#   [[ 47]
#    [ 42]
#    [ 60]
#    ...
#    [ 47]
#    [ 54]
#    [ 49]]
#
#   ...
#
#   [[ 91]
#    [ 65]
#    [ 46]
#    ...
#    [ 74]
#    [ 54]
#    [ 43]]
#
#   [[ 76]
#    [ 80]
#    [ 76]
#    ...
#    [108]
#    [ 69]
#    [ 46]]
#
#   [[ 77]
#    [ 74]
#    [ 81]
#    ...
#    [105]
#    [108]
#    [ 82]]]
#
#
#  [[[152]
#    [149]
#    [147]
#    ...
#    [129]
#    [139]
#    [121]]
#
#   [[149]
#    [152]
#    [150]
#    ...
#    [121]
#    [146]
#    [135]]
#
#   [[152]
#    [152]
#    [157]
#    ...
#    [112]
#    [121]
#    [145]]
#
#   ...
#
#   [[187]
#    [189]
#    [120]
#    ...
#    [184]
#    [185]
#    [188]]
#
#   [[188]
#    [189]
#    [193]
#    ...
#    [185]
#    [181]
#    [189]]
#
#   [[186]
#    [185]
#    [183]
#    ...
#    [193]
#    [181]
#    [183]]]
#
#
#  [[[ 29]
#    [ 25]
#    [ 21]
#    ...
#    [ 38]
#    [ 45]
#    [ 37]]
#
#   [[ 31]
#    [ 24]
#    [ 20]
#    ...
#    [ 36]
#    [ 36]
#    [ 40]]
#
#   [[ 28]
#    [ 21]
#    [ 21]
#    ...
#    [ 35]
#    [ 32]
#    [ 40]]
#
#   ...
#
#   [[ 28]
#    [ 29]
#    [ 26]
#    ...
#    [118]
#    [137]
#    [148]]
#
#   [[ 30]
#    [ 30]
#    [ 26]
#    ...
#    [151]
#    [158]
#    [164]]
#
#   [[ 32]
#    [ 30]
#    [ 27]
#    ...
#    [174]
#    [173]
#    [174]]]
#
#
#  ...
#
#
#  [[[243]
#    [220]
#    [207]
#    ...
#    [253]
#    [254]
#    [254]]
#
#   [[241]
#    [216]
#    [208]
#    ...
#    [250]
#    [255]
#    [255]]
#
#   [[237]
#    [215]
#    [202]
#    ...
#    [247]
#    [252]
#    [255]]
#
#   ...
#
#   [[255]
#    [252]
#    [230]
#    ...
#    [ 33]
#    [ 74]
#    [212]]
#
#   [[255]
#    [255]
#    [254]
#    ...
#    [148]
#    [218]
#    [254]]
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [253]]]
#
#
#  [[[253]
#    [252]
#    [254]
#    ...
#    [254]
#    [254]
#    [254]]
#
#   [[255]
#    [253]
#    [255]
#    ...
#    [255]
#    [251]
#    [254]]
#
#   [[252]
#    [251]
#    [253]
#    ...
#    [255]
#    [254]
#    [254]]
#
#   ...
#
#   [[251]
#    [254]
#    [255]
#    ...
#    [ 35]
#    [ 29]
#    [ 30]]
#
#   [[252]
#    [253]
#    [252]
#    ...
#    [ 24]
#    [ 23]
#    [ 20]]
#
#   [[251]
#    [251]
#    [251]
#    ...
#    [ 93]
#    [ 37]
#    [ 18]]]
#
#
#  [[[213]
#    [218]
#    [214]
#    ...
#    [253]
#    [252]
#    [254]]
#
#   [[209]
#    [213]
#    [217]
#    ...
#    [253]
#    [252]
#    [252]]
#
#   [[214]
#    [214]
#    [219]
#    ...
#    [252]
#    [253]
#    [252]]
#
#   ...
#
#   [[209]
#    [194]
#    [177]
#    ...
#    [251]
#    [255]
#    [255]]
#
#   [[210]
#    [190]
#    [195]
#    ...
#    [148]
#    [182]
#    [222]]
#
#   [[196]
#    [189]
#    [208]
#    ...
#    [ 97]
#    [ 92]
#    [ 83]]]]

# %%
test_features= extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\varsh\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\varsh\anaconda3\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\varsh\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
x_train=train_features/255.0
x_test=test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['image'])
# Out:
# LabelEncoder()

# %%
le = LabelEncoder()
le.fit(test['image'])
# Out:
# LabelEncoder()

# %%
all_labels = pd.concat([train['label'], test['label']], ignore_index=True)

# %%
print(all_labels)
# Out:
# 0           angry
# 1           angry
# 2           angry
# 3           angry
# 4           angry
#            ...
# 35882    surprise
# 35883    surprise
# 35884    surprise
# 35885    surprise
# 35886    surprise
# Name: label, Length: 35887, dtype: object

# %%
le = LabelEncoder()
le.fit(all_labels)
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train, num_classes = 7)
y_test = to_categorical(y_test, num_classes = 7)

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = 'accuracy' )
# Out:
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 60, validation_data = (x_test,y_test))
# Out:
# Epoch 1/60
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 226/226 [==============================] - 1130s 5s/step - loss: 1.8233 - accuracy: 0.2439 - val_loss: 1.8000 - val_accuracy: 0.2581
# Epoch 2/60
# 226/226 [==============================] - 706s 3s/step - loss: 1.7905 - accuracy: 0.2523 - val_loss: 1.7250 - val_accuracy: 0.3005
# Epoch 3/60
# 226/226 [==============================] - 700s 3s/step - loss: 1.7130 - accuracy: 0.3038 - val_loss: 1.6266 - val_accuracy: 0.3469
# Epoch 4/60
# 226/226 [==============================] - 1071s 5s/step - loss: 1.5998 - accuracy: 0.3656 - val_loss: 1.4552 - val_accuracy: 0.4506
# Epoch 5/60
# 226/226 [==============================] - 2714s 12s/step - loss: 1.5040 - accuracy: 0.4164 - val_loss: 1.3753 - val_accuracy: 0.4766
# Epoch 6/60
# 226/226 [==============================] - 1313s 6s/step - loss: 1.4420 - accuracy: 0.4425 - val_loss: 1.3009 - val_accuracy: 0.5051
# Epoch 7/60
# 226/226 [==============================] - 640s 3s/step - loss: 1.3872 - accuracy: 0.4669 - val_loss: 1.2736 - val_accuracy: 0.5078
# Epoch 8/60
# 226/226 [==============================] - 762s 3s/step - loss: 1.3577 - accuracy: 0.4796 - val_loss: 1.2470 - val_accuracy: 0.5236
# Epoch 9/60
# 226/226 [==============================] - 1032s 5s/step - loss: 1.3195 - accuracy: 0.4917 - val_loss: 1.2266 - val_accuracy: 0.5297
# Epoch 10/60
# 119/226 [==============>...............] - ETA: 8:17 - loss: 1.3049 - accuracy: 0.5019

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/angry/22.jpg'
print("original image is of ang")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of ang
# 1/1 [==============================] - 0s 110ms/step
# model prediction is  angry

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48,1),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 71ms/step
# model prediction is  sad

# %%
image = 'images/train/fear/2.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 90ms/step
# model prediction is  sad

# %%
image = 'images/train/disgust/299.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 49ms/step
# model prediction is  sad
